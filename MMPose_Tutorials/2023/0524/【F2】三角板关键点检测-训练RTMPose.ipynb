# %% [markdown]
# # 三角板关键点检测-训练RTMPose
#
# 同济子豪兄 2023-4-3 5-23

# %% [markdown]
# ## 进入 mmpose 主目录

# %%
import os
os.chdir('/mmpose')

# %% [markdown]
# ## 训练（建议在命令行中运行）

# %%
# !python tools/train.py /mmpose/data/config/rtmpose-s-ear.py
# Out:
# 06/03 18:19:32 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.7.10 (default, Feb 26 2021, 18:47:35) [GCC 7.3.0]
#     CUDA available: True
#     numpy_random_seed: 21
#     GPU 0: NVIDIA GeForce RTX 3060
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.1, V11.1.105
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 1.9.0
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2021.2-Product Build 20210312 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.1.2 (Git Hash 98be7e8afa711dc9b66c8ff3504129cb82013cdb)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.1
# ...

# %% [markdown]
# ## 测试集上评估模型精度

# %%
# !python tools/test.py /mmpose/work_dirs/rtmpose-s-ear/rtmpose-s-ear.py \
                      /mmpose/work_dirs/rtmpose-s-ear/epoch_300.pth
# Out:
# 06/04 00:14:24 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.7.10 (default, Feb 26 2021, 18:47:35) [GCC 7.3.0]
#     CUDA available: True
#     numpy_random_seed: 21
#     GPU 0: NVIDIA GeForce RTX 3060
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.1, V11.1.105
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 1.9.0
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2021.2-Product Build 20210312 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.1.2 (Git Hash 98be7e8afa711dc9b66c8ff3504129cb82013cdb)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.1
# ...
