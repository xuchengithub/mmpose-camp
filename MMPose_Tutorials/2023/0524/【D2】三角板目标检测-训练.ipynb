# %% [markdown]
# # 三角板目标检测-训练
#
# 同济子豪兄 2023-4-3

# %% [markdown]
# ## 进入mmdetection主目录

# %%
import os
os.chdir('/mmdetection')

# %% [markdown]
# ## 目标检测算法：Faster R CNN

# %%
# 建议在命令行中运行
# !python tools/train.py data/faster_r_cnn_triangle.py

# %% [markdown]
# ## 目标检测算法：RTMDet

# %%
# 建议在命令行中运行
# !python tools/train.py /mmdetection/data/config/rtmdet_tiny_ear.py
# Out:
# 06/03 17:22:09 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.7.10 (default, Feb 26 2021, 18:47:35) [GCC 7.3.0]
#     CUDA available: True
#     numpy_random_seed: 1268488536
#     GPU 0: NVIDIA GeForce RTX 3060
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.1, V11.1.105
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 1.9.0
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2021.2-Product Build 20210312 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.1.2 (Git Hash 98be7e8afa711dc9b66c8ff3504129cb82013cdb)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.1
# ...

# %% [markdown]
# ## 在`work_dirs`目录下，查看训练日志和训练得到的模型权重文件

# %% [markdown]
# ## 测试集上评估模型精度

# %%
# !python tools/test.py /mmdetection/work_dirs/rtmdet_tiny_ear/rtmdet_tiny_ear.py \
                      /mmdetection/work_dirs/rtmdet_tiny_ear/epoch_200.pth
# Out:
# 06/03 18:15:38 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.7.10 (default, Feb 26 2021, 18:47:35) [GCC 7.3.0]
#     CUDA available: True
#     numpy_random_seed: 605167472
#     GPU 0: NVIDIA GeForce RTX 3060
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.1, V11.1.105
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 1.9.0
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2021.2-Product Build 20210312 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.1.2 (Git Hash 98be7e8afa711dc9b66c8ff3504129cb82013cdb)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.1
# ...
